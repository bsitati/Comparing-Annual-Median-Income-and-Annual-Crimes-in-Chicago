# %%
import csv
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import numpy as np

# %%
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
crime_data = pd.read_csv("Crimes_-_2001_to_Present.csv", encoding="ISO-8859-1")

# %%
# Preview the first 5 lines of the loaded data 
crime_data.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11034701    JA366925  01/01/2001 11:00:00 AM       016XX E 86TH PL  1153
# 1  11227287    JB147188  10/08/2017 03:00:00 AM    092XX S RACINE AVE  0281
# 2  11227583    JB147595  03/28/2017 02:00:00 PM       026XX W 79TH ST  0620
# 3  11227293    JB147230  09/09/2017 08:17:00 PM  060XX S EBERHART AVE  0810
# 4  11227634    JB147599  08/26/2017 10:00:00 AM   001XX W RANDOLPH ST  0281
#
#           Primary Type                          Description  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2             BURGLARY                       UNLAWFUL ENTRY
# 3                THEFT                            OVER $500
# 4  CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False     False  ...   8.0            45.0        11
# 1            RESIDENCE   False     False  ...  21.0            73.0        02
# 2                OTHER   False     False  ...  18.0            70.0        05
# 3            RESIDENCE   False     False  ...  20.0            42.0        06
# 4          HOTEL/MOTEL   False     False  ...  42.0            32.0        02
#
#    X Coordinate Y Coordinate  Year              Updated On  Latitude  \
# 0           NaN          NaN  2001  08/05/2017 03:50:08 PM       NaN
# 1           NaN          NaN  2017  02/11/2018 03:57:41 PM       NaN
# 2           NaN          NaN  2017  02/11/2018 03:57:41 PM       NaN
# 3           NaN          NaN  2017  02/11/2018 03:57:41 PM       NaN
# 4           NaN          NaN  2017  02/11/2018 03:57:41 PM       NaN
#
#   Longitude  Location
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 22 columns]

# %%
# Description of crime data
crime_data.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  7.146139e+06  7.146139e+06  7.146092e+06  6.531312e+06    6.532655e+06
# mean   6.534422e+06  1.188921e+03  1.129473e+01  2.270921e+01    3.755227e+01
# std    3.218577e+06  7.030735e+02  6.945838e+00  1.383348e+01    2.153480e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    3.555666e+06  6.220000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    6.525852e+06  1.111000e+03  1.000000e+01  2.200000e+01    3.200000e+01
# 75%    9.322159e+06  1.731000e+03  1.700000e+01  3.400000e+01    5.700000e+01
# max    1.209601e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  7.077300e+06  7.077300e+06  7.146139e+06  7.077300e+06  7.077300e+06
# mean   1.164544e+06  1.885727e+06  2.008922e+03  4.184203e+01 -8.767170e+01
# std    1.712851e+04  3.265277e+04  5.463675e+00  8.985009e-02  6.199727e-02
# min    0.000000e+00  0.000000e+00  2.001000e+03  3.661945e+01 -9.168657e+01
# 25%    1.152947e+06  1.859132e+06  2.004000e+03  4.176883e+01 -8.771379e+01
# 50%    1.166036e+06  1.890649e+06  2.008000e+03  4.185573e+01 -8.766604e+01
# 75%    1.176358e+06  1.909232e+06  2.013000e+03  4.190672e+01 -8.762831e+01
# max    1.205119e+06  1.951622e+06  2.020000e+03  4.202291e+01 -8.752453e+01

# %%
uniq_crime_desc = crime_data['Primary Type'].unique() 
uniq_crime_desc

# crime_data.columns

# Description
# Out:
# array(['FINANCIAL IDENTITY THEFT OVER $ 300', 'NON-AGGRAVATED',
#        'UNLAWFUL ENTRY', 'OVER $500', 'PREDATORY',
#        'CRIM SEX ABUSE BY FAM MEMBER', 'AGG SEX ASSLT OF CHILD FAM MBR',
#        'TO PROPERTY', 'HARASSMENT BY ELECTRONIC MEANS', '$500 AND UNDER',
#        'AGG CRIM SEX ABUSE FAM MEMBER', 'CREDIT CARD FRAUD',
#        'SEX ASSLT OF CHILD BY FAM MBR',
#        'FINANCIAL IDENTITY THEFT $300 AND UNDER', 'FROM BUILDING',
#        'AGG CRIMINAL SEXUAL ABUSE', 'ATTEMPT NON-AGGRAVATED',
#        'CHILD ABUSE', 'FORCIBLE ENTRY', 'CRIMINAL SEXUAL ABUSE',
#        'CHILD PORNOGRAPHY', 'SIMPLE', 'EMBEZZLEMENT', 'AGGRAVATED: OTHER',
#        'HARASSMENT BY TELEPHONE', 'TELEPHONE THREAT',
#        'MANU/DELIVER:CRACK', 'MANU/DEL:CANNABIS 10GM OR LESS',
#        'POCKET-PICKING', 'POSS: CANNABIS MORE THAN 30GMS',
#        'INSURANCE FRAUD', 'CRIMINAL DRUG CONSPIRACY', 'POSS: CRACK',
#        'FORGERY', 'ATTEMPT - FINANCIAL IDENTITY THEFT',
#        'ILLEGAL USE CASH CARD', 'THEFT OF LABOR/SERVICES',
#        'FRAUD OR CONFIDENCE GAME', 'FOUND SUSPECT NARCOTICS',
#        'OTHER VEHICLE OFFENSE', 'AUTOMOBILE', 'ARMED: HANDGUN',
#        'SEX OFFENDER: FAIL TO REGISTER', 'TO VEHICLE', 'AGGRAVATED',
#        'SEX OFFENDER: FAIL REG NEW ADD', 'ENDANGERING LIFE/HEALTH CHILD',
#        'RETAIL THEFT', 'FORFEIT PROPERTY', 'TO LAND',
#        'STOLEN PROP: BUY/RECEIVE/POS.', 'THEFT BY LESSEE,MOTOR VEH',
#        'COUNTERFEIT CHECK', 'SEXUAL EXPLOITATION OF A CHILD',
#        'POSS: COCAINE', 'STRONGARM - NO WEAPON',
#        'UNLAWFUL POSS OF HANDGUN', 'POSS: METHAMPHETAMINES',
#        'OTHER CRIME INVOLVING PROPERTY', 'CRIMINAL DEFACEMENT',
#        'AGGRAVATED FINANCIAL IDENTITY THEFT', 'AGGRAVATED: HANDGUN',
#        'POSS: HEROIN(WHITE)', 'MANU/DELIVER: HEROIN (WHITE)',
#        'FINAN EXPLOIT-ELDERLY/DISABLED', 'PURSE-SNATCHING',
#        'OTHER CRIME AGAINST PERSON', 'AGGRAVATED OF A CHILD',
#        'COUNTERFEITING DOCUMENT', 'DOMESTIC BATTERY SIMPLE',
#        'OTHER OFFENSE', 'OTHER', 'POSS: CANNABIS 30GMS OR LESS',
#        'ATT AGG CRIMINAL SEXUAL ABUSE', 'BOGUS CHECK',
#        'ATT CRIM SEXUAL ABUSE',
#        'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
#        'INDECENT SOLICITATION/CHILD', 'UNAUTHORIZED VIDEOTAPING',
#        'OTHER WEAPONS VIOLATION', 'OBSCENE MATTER',
#        'MANU/DELIVER: HALLUCINOGEN', 'SALE/DIST OBSCENE MAT TO MINOR',
#        'TO RESIDENCE', 'GUN OFFENDER: DUTY TO REGISTER',
#        'CRIMINAL TRANSMISSION OF HIV', 'MANU/DELIVER:COCAINE',
#        'SELL/GIVE/DEL LIQUOR TO MINOR', 'SOLICIT FOR BUSINESS',
#        'CYCLE, SCOOTER, BIKE W-VIN', 'LIQUOR LICENSE VIOLATION',
#        'MANU/DEL:CANNABIS OVER 10 GMS', 'LOST PASSPORT',
#        'AGGRAVATED: OTHER DANG WEAPON',
#        'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY',
#        'EAVESDROPPING', 'THEFT/RECOVERY: AUTOMOBILE',
#        'OBSCENE TELEPHONE CALLS', 'IMPERSONATION',
#        'DELIVERY CONTAINER THEFT', 'AGGRAVATED: KNIFE/CUT INSTR',
#        'VEHICLE TITLE/REG OFFENSE', 'RECKLESS CONDUCT',
#        'DECEPTIVE COLLECTION PRACTICES', 'LICENSE VIOLATION',
#        'UNLAWFUL POSS AMMUNITION', 'PAY TV SERVICE OFFENSES',
#        'SOLICIT ON PUBLIC WAY', 'THEFT BY LESSEE,NON-VEH',
#        'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#        'INTIMIDATION', 'TO STATE SUP LAND', 'POSS: BARBITUATES',
#        'UNLAWFUL USE OTHER FIREARM', 'BY FIRE',
#        'ARMED:KNIFE/CUTTING INSTRUMENT', 'AGGRAVATED:KNIFE/CUTTING INSTR',
#        'ATTEMPT FORCIBLE ENTRY', 'AGGRAVATED: OTHER FIREARM',
#        'ILLEGAL CONSUMPTION BY MINOR', 'ATTEMPT: ARMED-KNIFE/CUT INSTR',
#        'POSS: SYNTHETIC DRUGS', 'ATTEMPT: ARMED-HANDGUN',
#        'ATTEMPT: STRONGARM-NO WEAPON', 'TRUCK, BUS, MOTOR HOME',
#        'ATT: AUTOMOBILE', 'AGG PO HANDS NO/MIN INJURY',
#        'SALE/DEL HYPODERMIC NEEDLE', 'AGGRAVATED VEHICULAR HIJACKING',
#        'POSS: PCP', 'BOMB THREAT', 'POSS: HEROIN(BRN/TAN)',
#        'ATTEMPT: ARMED-OTHER FIREARM', 'ARMED: OTHER DANGEROUS WEAPON',
#        'TO STATE SUP PROP', 'AGG: HANDS/FIST/FEET NO/MINOR INJURY',
#        'THEFT OF LOST/MISLAID PROP', 'PRO EMP HANDS NO/MIN INJURY',
#        'SOLICIT NARCOTICS ON PUBLICWAY', 'FINANCIAL ID THEFT:$300 &UNDER',
#        'PATRONIZING A PROSTITUTE', 'PUBLIC INDECENCY',
#        'POS: HYPODERMIC NEEDLE', 'INTERFERENCE JUDICIAL PROCESS',
#        'ALTER/FORGE PRESCRIPTION', 'GAME/AMUSEMENT DEVICE',
#        'FINANCIAL ID THEFT: OVER $300', 'ATTEMPT THEFT',
#        'VIOLATE ORDER OF PROTECTION', 'ATTEMPT POSSESSION NARCOTICS',
#        'UNLAWFUL USE/SALE AIR RIFLE', 'GAME/DICE', 'ANIMAL ABUSE/NEGLECT',
#        'AGGRAVATED OF A SENIOR CITIZEN', 'POSS FIREARM/AMMO:NO FOID CARD',
#        'UNLAWFUL RESTRAINT', 'ATT: TRUCK, BUS, MOTOR HOME',
#        'FALSE/STOLEN/ALTERED TRP', 'AGGRAVATED DOMESTIC BATTERY',
#        'POSS: HALLUCINOGENS', 'FORNICATION', 'MANU/DELIVER:BARBITUATES',
#        'CHILD ABDUCTION/STRANGER', 'CONTRIBUTE DELINQUENCY OF A CHILD',
#        'ATTEMPT ARSON',
#        'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#        'TO CITY OF CHICAGO PROPERTY', 'ATTEMPT POSSESSION CANNABIS',
#        'AGG PRO.EMP: OTHER DANG WEAPON', 'AGG PRO.EMP:KNIFE/CUTTING INST',
#        'UNLAWFUL USE OF RECORDED SOUND', 'UNIDENTIFIABLE RECORDING SOUND',
#        'POSS: HEROIN(BLACK TAR)', 'POSSESSION OF DRUG EQUIPMENT',
#        'SEX OFFENDER: PROHIBITED ZONE', 'POSSESSION OF BURGLARY TOOLS',
#        'BRIBERY', 'RECKLESS FIREARM DISCHARGE',
#        'RESIST/OBSTRUCT/DISARM OFFICER', 'FALSE POLICE REPORT',
#        'UNLAWFUL USE OTHER DANG WEAPON', 'AGG: FINANCIAL ID THEFT',
#        'THEFT/RECOVERY: TRUCK,BUS,MHOME', 'OFFICIAL MISCONDUCT',
#        'COMPOUNDING A CRIME', 'MONEY LAUNDERING',
#        'MANU/DELIVER: HEROIN(BRN/TAN)', 'ATTEMPT AGG: OTHER',
#        'COMPUTER FRAUD', 'ILLEGAL POSSESSION BY MINOR',
#        'ATTEMPT FINANCIAL IDENTITY THEFT',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#        'CHILD ABANDONMENT', 'PROBATION VIOLATION', 'CHILD ABDUCTION',
#        'SOLICIT OFF PUBLIC WAY', 'INSTITUTIONAL VANDALISM',
#        'CALL OPERATION', 'IN TAVERN', 'ATTEMPT: AGGRAVATED',
#        'AGGRAVATED PO: OTHER DANG WEAP', 'OBSTRUCTING JUSTICE',
#        'EXTORTION', 'UNLAWFUL SALE HANDGUN',
#        'UNLAWFUL SALE OTHER FIREARM', 'MANU/DELIVER:PCP',
#        'UNLAWFUL USE OF A COMPUTER', 'BIGAMY', 'PAROLE VIOLATION',
#        'VEHICULAR HIJACKING', 'UNLAWFUL POSS OTHER FIREARM',
#        'UNLAWFUL USE HANDGUN', 'ILLEGAL POSSESSION CASH CARD',
#        'ARMED: OTHER FIREARM', 'TO FIRE FIGHT.APP.EQUIP', 'MOB ACTION',
#        'ATTEMPT: ARMED-OTHER DANG WEAP', 'AGGRAVATED PO: HANDGUN',
#        'ARSON THREAT', 'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN',
#        'CANNABIS PLANT', 'FROM COIN-OP MACHINE/DEVICE',
#        'VIO BAIL BOND: DOM VIOLENCE', 'TO AIRPORT',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM',
#        'COMPELLING ORG MEMBERSHIP', 'AGG: HANDS/FIST/FEET SERIOUS INJURY',
#        'UNLAWFUL INTERFERE/VISITATION', 'AGG PRO.EMP: HANDGUN',
#        'INTOXICATING COMPOUNDS', 'MANU/DELIVER:SYNTHETIC DRUGS',
#        'KEEP PLACE OF PROSTITUTION', 'HOME INVASION',
#        'SALE/DEL DRUG PARAPHERNALIA', 'KIDNAPPING', 'LOTTERY/PARI-MUTUEL',
#        'OBSTRUCTING IDENTIFICATION', 'OTHER PROSTITUTION OFFENSE',
#        'MANU/DELIVER:LOOK-ALIKE DRUG',
#        'VIOLENT OFFENDER: ANNUAL REGISTRATION',
#        'MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#        'TAMPER WITH MOTOR VEHICLE', 'OTHER VIOLATION',
#        'VIOLATION OF STALKING NO CONTACT ORDER',
#        'MANU/DELIVER:AMPHETAMINES', 'MANU/DELIVER: METHAMPHETAMINES',
#        'INDECENT SOLICITATION/ADULT', 'AGGRAVATED CRIMINAL SEXUAL ABUSE',
#        'PROHIBITED PLACES', 'OBSCENITY', 'CYBERSTALKING', 'LIBRARY THEFT',
#        'WIREROOM/HORSES', 'POSS: AMPHETAMINES', 'BOOKMAKING/SPORTS',
#        'INTERFERE W/ EMERGENCY EQUIP', 'FIREARM REGISTRATION VIOLATION',
#        'VIOLATION OF CIVIL NO CONTACT ORDER', 'PIMPING', 'ESCAPE',
#        'SOLICIT FOR PROSTITUTE', 'FIRST DEGREE MURDER',
#        'FAILURE TO KEEP HYPO RECORDS', 'AGG PO HANDS ETC SERIOUS INJ',
#        'HARBOR RUNAWAY', 'ANIMAL FIGHTING', 'FALSE FIRE ALARM',
#        'AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY',
#        'SEX RELATION IN FAMILY', 'DEL CONT SUBS TO PERSON <18',
#        'FOID - REVOCATION', 'PEEPING TOM',
#        'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE NO VIN',
#        'ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN',
#        'POSSESSION: SYNTHETIC MARIJUANA', 'PANDERING', 'GAME/CARDS',
#        'CONTRIBUTE CRIM DELINQUENCY JUVENILE', 'MINOR MISREPRESENT AGE',
#        'MARRYING A BIGAMIST', 'AGGRAVATED PO: KNIFE/CUT INSTR',
#        'MANU/DELIVER:HEROIN(BLACK TAR)', 'AGGRAVATED PO:KNIFE/CUT INSTR',
#        'ILLEGAL ILL LOTTERY', 'ATT AGG CRIM SEXUAL ABUSE', 'BY EXPLOSIVE',
#        'ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE',
#        'SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER', 'COMMERCIAL SEX ACTS',
#        'GUN OFFENDER: ANNUAL REGISTRATION', 'ARMED VIOLENCE',
#        'JUVENILE PIMPING', 'AGGRAVATED - OTHER',
#        'ARSONIST: FAIL TO REGISTER NEW ADDRESS',
#        'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#        'AGGRAVATED COMPUTER TAMPERING',
#        'INDECENT SOLICITATION OF A CHILD',
#        'NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES',
#        'CYCLE, SCOOTER, BIKE NO VIN', 'AGGRAVATED - HANDGUN',
#        'GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION',
#        'PUBLIC DEMONSTRATION', 'VIOLENT OFFENDER: DUTY TO REGISTER',
#        'AGGRAVATED POLICE OFFICER - HANDGUN',
#        'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#        'ARMED WHILE UNDER THE INFLUENCE', 'LICENSED PREMISE',
#        'SALE TOBACCO PRODUCTS TO MINOR', 'ABUSE/NEGLECT: CARE FACILITY',
#        'OBSTRUCTING SERVICE', 'AGG PRO EMP HANDS SERIOUS INJ',
#        'AGGRAVATED OF A UNBORN CHILD', 'VIOLATION GPS MONITORING DEVICE',
#        'ATTEMPT: CYCLE, SCOOTER, BIKE NO VIN',
#        'HAZARDOUS MATERIALS VIOLATION', 'POS: PORNOGRAPHIC PRINT',
#        'UNLAWFUL POSSESSION - HANDGUN',
#        'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#        'ARSONIST: ANNUAL REGISTRATION',
#        'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
#        'SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR',
#        'POS: EXPLOSIVE/INCENDIARY DEV', 'ATTEMPT AGG: KNIFE/CUT INSTR',
#        'OF UNBORN CHILD', 'ARMED - HANDGUN', 'ATTEMPT AGG: HANDGUN',
#        'OTHER ARSON/EXPLOSIVE INCIDENT', 'UNLAWFUL USE - HANDGUN',
#        'VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS',
#        'AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'BOARD PLANE WITH WEAPON', 'ATTEMPT ARMED - HANDGUN',
#        'UNLAWFUL USE OF BODY ARMOR', 'STRONG ARM - NO WEAPON',
#        'ARMED - OTHER DANGEROUS WEAPON',
#        'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'AGG PRO.EMP: OTHER FIREARM', 'THEFT BY LESSEE, MOTOR VEHICLE',
#        'SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS',
#        'AGGRAVATED PO: OTHER FIREARM', 'EMPLOY MINOR',
#        'DELIVER CANNABIS TO PERSON <18',
#        'AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'AGGRAVATED - OTHER DANGEROUS WEAPON',
#        'INTIMIDATION OF LAW ENFORCEMENT OFFICIAL', 'ATTEMPT AGGRAVATED',
#        'CYCLE, SCOOTER, BIKE WITH VIN', 'VIOLATION OF SUMMARY CLOSURE',
#        'AGGRAVATED: KNIFE / CUTTING INSTRUMENT',
#        'SEXUAL RELATIONS IN FAMILY', 'SEX OFFENDER - FAIL TO REGISTER',
#        'ATTEMPT AGGRAVATED - OTHER', 'INVOLUNTARY SERVITUDE',
#        'STOLEN PROPERTY BUY / RECEIVE / POSSESS',
#        'ATTEMPT CRIMINAL SEXUAL ABUSE',
#        'ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON',
#        'THEFT OF LABOR / SERVICES',
#        'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES',
#        'RECKLESS HOMICIDE', 'COMPELLING CONFESSION',
#        'CONCEALED CARRY LICENSE REVOCATION',
#        'ENDANGERING LIFE / HEALTH OF CHILD',
#        'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#        'ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT',
#        'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
#        'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON',
#        'ATTEMPT STRONG ARM - NO WEAPON', 'UNLAWFUL USE - OTHER FIREARM',
#        'AGGRAVATED P.O. - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'ARSONIST - ANNUAL REGISTRATION',
#        'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#        'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'CONTRIBUTE TO THE DELINQUENCY OF CHILD',
#        'AGGRAVATED - OTHER FIREARM', 'VIOLATION OF SMOKING BAN',
#        'ARMED - KNIFE / CUTTING INSTRUMENT',
#        'AGGRAVATED DOMESTIC BATTERY - HANDGUN', 'FORCIBLE DETENTION',
#        'ARMED - OTHER FIREARM', 'ARSONIST - FAIL TO REGISTER NEW ADDRESS',
#        'ATTEMPT ARMED - OTHER DANGEROUS WEAPON',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANGEROUS WEAPON',
#        'DEFACE IDENT MARKS OF FIREARM',
#        'POSSESS - CANNABIS MORE THAN 30 GRAMS', 'ATTEMPT - AUTOMOBILE',
#        'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS',
#        'THEFT / RECOVERY - AUTOMOBILE',
#        'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
#        'THEFT OF LOST / MISLAID PROPERTY', 'STRONGARM: NO WEAPON',
#        'CONT SUBS:FAIL TO MAINT RECORD', 'ALTER / FORGE PRESCRIPTION',
#        'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#        'POSSESS - CRACK', 'THEFT BY LESSEE, NON-MOTOR VEHICLE',
#        'UNLAWFUL POSSESSION - OTHER FIREARM',
#        'AGGRAVATED: OTHER DANGEROUS WEAPON', 'AIDING ARRESTEE ESCAPE',
#        'TO STATE SUPPORTED PROPERTY',
#        'AGGRAVATED DOMESTIC BATTERY: KNIFE / CUTTING INSTSTRUMENT',
#        'ATTEMPT ARMED - OTHER FIREARM', 'POSSESS - HEROIN (WHITE)',
#        'ATTEMPT STRONG ARM: NO WEAPON',
#        'UNLAWFUL VISITATION INTERFERENCE', 'FALSE / STOLEN / ALTERED TRP',
#        'ATTEMPT ARMED: HANDGUN', 'ABUSE / NEGLECT - CARE FACILITY',
#        'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#        'VIOLENT OFFENDER - ANNUAL REGISTRATION',
#        'RESIST / OBSTRUCT / DISARM OFFICER', 'CHILD ABDUCTION / STRANGER',
#        'MANUFACTURE / DELIVER -  HEROIN (WHITE)',
#        'ANIMAL ABUSE / NEGLECT',
#        'AGGRAVATED: HANDS / FIST / FEET NO / MINOR INJURY',
#        'POSSESS - COCAINE', 'MANUFACTURE / DELIVER - HALLUCINOGEN',
#        'MANUFACTURE / DELIVER - CRACK',
#        'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
#        'SELL / GIVE / DELIVER LIQUOR TO MINOR',
#        'POSSESS - SYNTHETIC DRUGS', 'POSSESS - BARBITURATES',
#        'AGGRAVATED PO: OTHER DANGEROUS WEAPON',
#        'POSSESS - CANNABIS 30 GRAMS OR LESS',
#        'MANUFACTURE / DELIVER - SYNTHETIC DRUGS',
#        'SOLICIT NARCOTICS ON PUBLIC WAY', 'POSSESS - METHAMPHETAMINE',
#        'MANUFACTURE / DELIVER - BARBITURATES',
#        'AGGRAVATED: HANDS / FIST / FEET SERIOUS INJURY',
#        'UNLAWFUL POSSESSION - AMMUNITION',
#        'POSSESS - HEROIN (TAN / BROWN TAR)',
#        'PROTECTED EMPLOYEE: HANDS NO / MIN INJURY',
#        'POSSESS - HALLUCINOGENS',
#        'MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS',
#        'VEHICLE TITLE / REGISTRATION OFFENSE',
#        'GUN OFFENDER - DUTY TO REPORT CHANGE OF INFORMATION',
#        'GUN OFFENDER - ANNUAL REGISTRATION', 'POSSESS - PCP',
#        'UNLAWFUL USE - OTHER DANGEROUS WEAPON',
#        'UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL',
#        'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN',
#        'MANUFACTURE / DELIVER - PCP', 'GUN OFFENDER - DUTY TO REGISTER',
#        'MANUFACTURE / DELIVER - COCAINE',
#        'VIOLENT OFFENDER - FAIL TO REGISTER NEW ADDRESS',
#        'CONTRIBUTE TO THE CRIMINAL DELINQUENCY OF CHILD',
#        'SALE OF TOBACCO PRODUCTS TO MINOR',
#        'MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)',
#        'MANUFACTURE / DELIVER - HEROIN (BLACK TAR)',
#        'SALE / DELIVER - DRUG PARAPHERNALIA',
#        'AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM',
#        'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE',
#        'THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME',
#        'SOLICITING FOR A PROSTITUTE', 'POSSESS - AMPHETAMINES',
#        'UNLAWFUL USE / SALE OF AIR RIFLE',
#        'ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#        'DEFACE IDENTIFICATION MARKS OF FIREARM',
#        'FROM COIN-OPERATED MACHINE OR DEVICE', 'SOLICITING FOR BUSINESS',
#        'ATTEMPT - TRUCK, BUS, MOTOR HOME',
#        'AGGRAVATED DOMESTIC BATTERY - OTHER FIREARM',
#        'POSSESSION OF PORNOGRAPHIC PRINT', 'POSSESS - HEROIN (BLACK TAR)',
#        'INVOLUNTARY MANSLAUGHTER',
#        'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN',
#        'ATTEMPT AGGRAVATED - HANDGUN', 'LOOTING',
#        'OTHER ARSON / EXPLOSIVE INCIDENT',
#        'AGGRAVATED POLICE OFFICER - OTHER FIREARM',
#        'INDECENT SOLICITATION OF AN ADULT',
#        'AGGRAVATED OF AN UNBORN CHILD',
#        'ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN',
#        'POSSESSION - EXPLOSIVE / INCENDIARY DEVICE', 'WIREROOM/SPORTS',
#        'PATRONIZE JUVENILE PROSTITUTE', 'LIBRARY VANDALISM',
#        'SELL/ADVERTISE FIREWORKS',
#        'NOTIFICATION OF STALKING - NO CONTACT ORDER',
#        'INTERFERE W/ HIGHER EDUCATION', 'ATTEMPT AGG: OTHER DANG WEAPON',
#        'POSS: LOOK-ALIKE DRUGS', 'EDUCATIONAL INTIMIDAITON',
#        'NOTIFICATION OF CIVIL NO CONTACT ORDER',
#        'POS: CHEMICAL/DRY-ICE DEVICE', 'THEFT RETAIL',
#        'CONCEALING/AIDING A FUGITIVE',
#        'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL', 'FOUND PASSPORT',
#        'FAIL REGISTER LIC:CONT SUBS', 'POSS. KEYS OR DEV.TO COIN MACH',
#        'REFUSING TO AID AN OFFICER', 'ATTEMPT AGG: OTHER FIREARM',
#        'CONTRABAND IN PRISON', 'CAB OPERATION',
#        'ARSONIST: DUTY TO REGISTER',
#        'GUN OFFENDER NOTIFICATION-NO CONTACT', 'ALTER COINS',
#        'USE OF METAL PIERCING BULLETS', 'BOOKMAKING/HORSES',
#        'AGG RITUAL MUT:KNIFE/CUTTING I', 'DOMESTIC VIOLENCE',
#        'LOTTERY/OTHER', 'AGG RITUAL MUT:OTH DANG WEAPON',
#        'REGISTER OF SALES BY DEALER', 'OVER $300',
#        'VIOL CHARITABLE GAME ACT', 'AGG RITUAL MUT:HANDGUN',
#        'POLICY/OTHER', '$300 AND UNDER', 'BOLITA OR BOLI PUL/WRITER',
#        'BOLITA OR BOLI PUL/RUNNER', 'LOTTERY/PARLAY CARDS', 'ADULTRY',
#        'BOLITA OR BOLI PUL/OFFICE',
#        'AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY',
#        'CALCULATED CANNABIS CONSPIRACY', 'SPORTS TAMPERING',
#        'NATIONAL LOTTERY', 'REGISTER FED GAMBLING STAMP',
#        'KEEP PLACE OF JUV PROSTITUTION', 'DISCLOSE DV VICTIM LOCATION'],
#       dtype=object)

# %%
uniq_crime_desc = crime_data['FBI Code'].unique() 
uniq_crime_desc
# Out:
# array(['11', '02', '05', '06', '17', '14', '26', '20', '08B', '12', '08A',
#        '18', '10', '07', '03', '13', '15', '04B', '04A', '22', '16', '24',
#        '09', '19', '01A', '01B'], dtype=object)

# %%
# crime data without null value in Longitude ... assume the same null for latitude
not_null_crime_data = crime_data[crime_data['Longitude'].notnull()]
not_null_crime_data.head()
# Out:
#              ID Case Number                    Date  \
# 63300  11665567    JC234307  04/10/2019 04:37:00 PM
# 63384  11667963    JC235212  04/12/2019 04:08:00 PM
# 63385  11667968    JC237058  04/19/2019 01:57:00 PM
# 63461  11668309    JC238187  04/25/2019 05:20:00 PM
# 63865  11692179    JC261724  05/13/2019 05:26:00 PM
#
#                                      Block  IUCR                Primary Type  \
# 63300                   102XX S VERNON AVE  1562                 SEX OFFENSE
# 63384                   032XX N KEELER AVE  1754  OFFENSE INVOLVING CHILDREN
# 63385                  002XX N LARAMIE AVE  1752  OFFENSE INVOLVING CHILDREN
# 63461  108XX S DR MARTIN LUTHER KING JR DR  0486                     BATTERY
# 63865                   090XX S RACINE AVE  0560                     ASSAULT
#
#                                              Description  \
# 63300                   AGGRAVATED CRIMINAL SEXUAL ABUSE
# 63384                     AGG SEX ASSLT OF CHILD FAM MBR
# 63385  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 63461                            DOMESTIC BATTERY SIMPLE
# 63865                                             SIMPLE
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 63300  SCHOOL - PUBLIC BUILDING   False     False  ...   9.0            49.0
# 63384                 RESIDENCE   False      True  ...  30.0            16.0
# 63385                 RESIDENCE   False      True  ...  28.0            25.0
# 63461                 RESIDENCE   False      True  ...   9.0            49.0
# 63865                    STREET   False     False  ...  21.0            73.0
#
#        FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 63300        17     1181051.0    1837225.0  2019  04/17/2020 03:50:24 PM
# 63384        02     1147835.0    1921408.0  2019  10/02/2019 04:13:24 PM
# 63385        17     1141669.0    1901165.0  2019  03/18/2020 03:52:17 PM
# 63461       08B     1180832.0    1833222.0  2019  06/30/2019 03:56:27 PM
# 63865       08A     1169908.0    1844927.0  2019  06/30/2019 03:56:27 PM
#
#         Latitude  Longitude                       Location
# 63300  41.708589 -87.612583     (41.708589, -87.612583094)
# 63384  41.940298 -87.732066  (41.940297617, -87.732066473)
# 63385  41.884865 -87.755230  (41.884865037, -87.755230327)
# 63461  41.697609 -87.613508  (41.697609261, -87.613507612)
# 63865  41.729973 -87.653167  (41.729973132, -87.653166753)
#
# [5 rows x 22 columns]

# %%
# Added column "Crime" with FBI Uniform crime report

# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '01A', 'Crime'] = ' Murder and Nonnegligent Manslaughter'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '01B', 'Crime'] = 'Manslaughter by Negligence'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '02', 'Crime'] = 'Forcible Rape'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '03', 'Crime'] = 'Robbery'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '04A', 'Crime'] = 'Aggravated Assaul- Firearm'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '04B', 'Crime'] = 'Aggravated Assaul-Knife or Cutting Instrument'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '05', 'Crime'] = 'Burglary'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '06', 'Crime'] = 'Larceny-thefT'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '07', 'Crime'] = 'Motor Vehicle Thef'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '08A', 'Crime'] = 'Arson-Structural'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '08B', 'Crime'] = 'Arson-Structural'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '09', 'Crime'] = 'Other Assaults'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '10', 'Crime'] = 'Forgery and Counterfeiting'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '12', 'Crime'] = 'Embezzlement'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '13', 'Crime'] = 'Stolen Property: Buying, Receiving, Possessing'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '14', 'Crime'] = 'Vandalism'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '15', 'Crime'] = 'Weapons: Carrying, Possessing, etc'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '16', 'Crime'] = ' Prostitution and Commercialized Vice'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '17', 'Crime'] = 'Sex Offenses'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '18', 'Crime'] = 'Drug Abuse Violations'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '19', 'Crime'] = 'Gambling'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '20', 'Crime'] = 'Offenses Against the Family and Children'
# not_null_crime_data.loc[not_null_crime_data['FBI Code'] == '26', 'Crime'] = 'All Other Offenses'

# %%
# Describe filtered data 
not_null_crime_data.describe()

not_null_crime_data.head()
# Out:
#              ID Case Number                    Date  \
# 63300  11665567    JC234307  04/10/2019 04:37:00 PM
# 63384  11667963    JC235212  04/12/2019 04:08:00 PM
# 63385  11667968    JC237058  04/19/2019 01:57:00 PM
# 63461  11668309    JC238187  04/25/2019 05:20:00 PM
# 63865  11692179    JC261724  05/13/2019 05:26:00 PM
#
#                                      Block  IUCR                Primary Type  \
# 63300                   102XX S VERNON AVE  1562                 SEX OFFENSE
# 63384                   032XX N KEELER AVE  1754  OFFENSE INVOLVING CHILDREN
# 63385                  002XX N LARAMIE AVE  1752  OFFENSE INVOLVING CHILDREN
# 63461  108XX S DR MARTIN LUTHER KING JR DR  0486                     BATTERY
# 63865                   090XX S RACINE AVE  0560                     ASSAULT
#
#                                              Description  \
# 63300                   AGGRAVATED CRIMINAL SEXUAL ABUSE
# 63384                     AGG SEX ASSLT OF CHILD FAM MBR
# 63385  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 63461                            DOMESTIC BATTERY SIMPLE
# 63865                                             SIMPLE
#
#            Location Description  Arrest  Domestic  ...  Community Area  \
# 63300  SCHOOL - PUBLIC BUILDING   False     False  ...            49.0
# 63384                 RESIDENCE   False      True  ...            16.0
# 63385                 RESIDENCE   False      True  ...            25.0
# 63461                 RESIDENCE   False      True  ...            49.0
# 63865                    STREET   False     False  ...            73.0
#
#        FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 63300        17     1181051.0     1837225.0  2019  04/17/2020 03:50:24 PM
# 63384        02     1147835.0     1921408.0  2019  10/02/2019 04:13:24 PM
# 63385        17     1141669.0     1901165.0  2019  03/18/2020 03:52:17 PM
# 63461       08B     1180832.0     1833222.0  2019  06/30/2019 03:56:27 PM
# 63865       08A     1169908.0     1844927.0  2019  06/30/2019 03:56:27 PM
#
#         Latitude  Longitude                       Location             Crime
# 63300  41.708589 -87.612583     (41.708589, -87.612583094)      Sex Offenses
# 63384  41.940298 -87.732066  (41.940297617, -87.732066473)     Forcible Rape
# 63385  41.884865 -87.755230  (41.884865037, -87.755230327)      Sex Offenses
# 63461  41.697609 -87.613508  (41.697609261, -87.613507612)  Arson-Structural
# 63865  41.729973 -87.653167  (41.729973132, -87.653166753)  Arson-Structural
#
# [5 rows x 23 columns]

# %%
# Create the connection using the imported create_engine function and 
# then invoking the connect method on it.
engine = create_engine('sqlite:///Chicago_crime.db', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2020-07-06 23:29:15,231 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-07-06 23:29:15,232 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-06 23:29:15,233 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-07-06 23:29:15,234 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "chi_crime_mapping"
final_map_crime_data.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
sqlite_connection.close()
# Out:
# 2020-07-06 23:29:23,157 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("chi_crime_mapping")
# 2020-07-06 23:29:23,158 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-06 23:29:23,186 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("chi_crime_mapping")
# 2020-07-06 23:29:23,187 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-06 23:29:23,189 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE chi_crime_mapping (
# 	"index" BIGINT,
# 	"CASE#" TEXT,
# 	"DATE  OF OCCURRENCE" TEXT,
# 	" PRIMARY DESCRIPTION" TEXT,
# 	" SECONDARY DESCRIPTION" TEXT,
# 	" LOCATION DESCRIPTION" TEXT,
# 	"ARREST" TEXT,
# 	"DOMESTIC" TEXT,
# 	"X COORDINATE" FLOAT,
# 	"Y COORDINATE" FLOAT,
# 	"LATITUDE" FLOAT,
# 	"LONGITUDE" FLOAT,
# 	"LOCATION" TEXT
# )
#
#
# 2020-07-06 23:29:23,190 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-06 23:29:23,301 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-07-06 23:29:23,302 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_chi_crime_mapping_index ON chi_crime_mapping ("index")
# 2020-07-06 23:29:23,303 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-06 23:29:23,398 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-07-06 23:29:24,550 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-07-06 23:29:27,094 INFO sqlalchemy.engine.base.Engine INSERT INTO chi_crime_mapping ("index", "CASE#", "DATE  OF OCCURRENCE", " PRIMARY DESCRIPTION", " SECONDARY DESCRIPTION", " LOCATION DESCRIPTION", "ARREST", "DOMESTIC", "X COORDINATE", "Y COORDINATE", "LATITUDE", "LONGITUDE", "LOCATION") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-07-06 23:29:27,094 INFO sqlalchemy.engine.base.Engine ((1, 'JD205528', '04/09/2020 02:00:00 PM', 'CRIMINAL DAMAGE', 'TO VEHICLE', 'STREET', 'N', 'N', 1168260.0, 1885596.0, 41.841609341, -87.65803375, '(41.841609341, -87.65803375)'), (2, 'JD177980', '03/08/2020 02:15:00 AM', 'CRIMINAL TRESPASS', 'TO LAND', 'APARTMENT', 'Y', 'N', 1180028.0, 1862391.0, 41.777670858, -87.61556066, '(41.777670858, -87.61556066)'), (8, 'JD218694', '04/27/2020 10:49:00 PM', 'CRIMINAL DAMAGE', 'CRIMINAL DEFACEMENT', 'RESIDENCE', 'N', 'Y', 1148850.0, 1932008.0, 41.969365232, -87.72806082, '(41.969365232, -87.72806082)'), (9, 'JD218865', '04/27/2020 06:20:00 PM', 'CRIMINAL DAMAGE', 'TO VEHICLE', 'STREET', 'N', 'N', 1181614.0, 1871679.0, 41.803121487, -87.609459729, '(41.803121487, -87.609459729)'), (10, 'JD218362', '04/27/2020 02:04:00 PM', 'BATTERY', 'DOMESTIC BATTERY SIMPLE', 'STREET', 'N', 'Y', 1197319.0, 1846268.0, 41.733014687, -87.552709149, '(41.733014687, -87.552709149)'), (11, 'JD219384', '04/27/2020 06:00:00 PM', 'THEFT', '$500 AND UNDER', 'APARTMENT', 'N', 'N', 1173777.0, 1837039.0, 41.708242575999996, -87.639226455, '(41.708242576, -87.639226455)'), (12, 'JD213704', '04/20/2020 09:30:00 PM', 'ROBBERY', 'STRONG ARM - NO WEAPON', 'RESIDENCE', 'N', 'N', 1177482.0, 1834509.0, 41.701217148000005, -87.625734707, '(41.701217148, -87.625734707)'), (13, 'JD218592', '04/27/2020 05:00:00 PM', 'MOTOR VEHICLE THEFT', 'AUTOMOBILE', 'STREET', 'N', 'N', 1194024.0, 1853729.0, 41.75356967, -87.56453584100001, '(41.75356967, -87.564535841)')  ... displaying 10 of 231706 total bound parameter sets ...  (233032, 'JC405144', '08/23/2019 11:00:00 PM', 'THEFT', 'OVER $500', 'STREET', 'N', 'N', 1163350.0, 1909452.0, 41.907176814, -87.675380762, '(41.907176814, -87.675380762)'), (233033, 'JC379670', '08/05/2019 12:30:00 PM', 'BATTERY', 'DOMESTIC BATTERY SIMPLE', 'RESIDENCE', 'N', 'Y', 1175245.0, 1855561.0, 41.759036773000005, -87.633298885, '(41.759036773, -87.633298885)'))
# 2020-07-06 23:29:28,407 INFO sqlalchemy.engine.base.Engine COMMIT
